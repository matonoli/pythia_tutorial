# %% [markdown]
# # 🚀 Pythia8 + ROOT Hands-On Exercise
# ### By Oliver Matonoha
#
# In this Jupyter notebook, we will:
# - Use **Pythia8** to simulate high-energy collisions and generate events for RHIC and LHC energies
# - Analyze specific particles in given decay channels such as **\( J/\psi \to \mu^+ \mu^- \)**.
# - Explore **Multiple Partonic Interactions (MPI)**.
# - Use **ROOT** to visualize results, create histograms, and store data in **ROOT trees** for further analysis.
#
# 📌 **Tip:** You can access the Python interface documentation of Pythia8 using:
# ```python
# help(pythia8)

# %% [markdown]
# First, we load the libraries:

# %%
import pythia8
import ROOT

# For interactive canvas, uncomment the following line
#%jsroot on

# Displays the help for the pythia8 module
help(pythia8)
# Out:
# In module 'Darwin':
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/libkern/arm/OSByteOrder.h:14:1: error: '_OSSwapInt16' has different definitions in different modules; definition in module 'Darwin.libkern.OSByteOrder' first difference is return type is 'uint16_t' (aka 'unsigned short')
# uint16_t
# ^~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/libkern/arm/_OSByteOrder.h:49:1: note: but in 'DarwinFoundation.OSByteOrder' found different return type '__uint16_t' (aka 'unsigned short')
# __uint16_t
# ^~~~~~~~~~
# In module 'Darwin':
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/libkern/arm/OSByteOrder.h:24:1: error: '_OSSwapInt32' has different definitions in different modules; definition in module 'Darwin.libkern.OSByteOrder' first difference is return type is 'uint32_t' (aka 'unsigned int')
# uint32_t
# ^~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/libkern/arm/_OSByteOrder.h:59:1: note: but in 'DarwinFoundation.OSByteOrder' found different return type '__uint32_t' (aka 'unsigned int')
# __uint32_t
# ^~~~~~~~~~
# In module 'Darwin':
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/libkern/arm/OSByteOrder.h:40:1: error: '_OSSwapInt64' has different definitions in different modules; definition in module 'Darwin.libkern.OSByteOrder' first difference is return type is 'uint64_t' (aka 'unsigned long long')
# uint64_t
# ^~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/libkern/arm/_OSByteOrder.h:75:1: note: but in 'DarwinFoundation.OSByteOrder' found different return type '__uint64_t' (aka 'unsigned long long')
# __uint64_t
# ^~~~~~~~~~
# In module 'Darwin':
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/xlocale/_ctype.h:55:1: error: '__toupper_l' has different definitions in different modules; definition in module 'Darwin.C.xlocale._ctype' first difference is function body
# __toupper_l(__darwin_ct_rune_t _c, locale_t _l)
# ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/xlocale/_ctype.h:56:2: note: but in '_DarwinFoundation2._ctype.xlocale' found a different body
# {
# ~^
# In module 'Darwin':
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/xlocale/_ctype.h:62:1: error: '__tolower_l' has different definitions in different modules; definition in module 'Darwin.C.xlocale._ctype' first difference is function body
# __tolower_l(__darwin_ct_rune_t _c, locale_t _l)
# ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/xlocale/_ctype.h:63:2: note: but in '_DarwinFoundation2._ctype.xlocale' found a different body
# {
# ~^
# Welcome to JupyROOT 6.28/00
# Help on module pythia8:
#
# NAME
#     pythia8
#
# DESCRIPTION
#     * Documentation through the built-in help function in Python provides
#       the relevant mappings between the Python interface and the C++
#       code. For documentation on the purpose of the code, see the user
#       HTML manual and Doxygen.
#     * Templated C++ types are returned as native Python types,
#       e.g. vectors are returned as lists, etc. Similarly, native Python
#       types can be passed as arguments and are converted to their
#       equivalent C++ templates.
#     * No difference is made between passing by reference or pointer;
#       methods in C++ which take a pointer as an argument in Python simply
#       take the object, e.g. foo(Vec4*) and foo(Vec4&) are the same in the
#       Python interface.
#     * All operators defined in C++, e.g. Vec4*double are available. Note
#       that reverse operators are not, e.g. double*Vec4.
#     * Classes with defined [] operators are iterable, using standard
#       Python iteration, e.g. for prt in pythia.event.
#     * Classes with a << operator can be printed via the built-in print
#       function in Python. Note this means that a string representation via
#       str is also available for these classes in Python.
#     * Derived classes in Python can be passed back to PYTHIA, and should
#       be available for all classes. See main10.py for a direct Python
#       translation of the C++ main10.cc example which uses a derived class
#       from the UserHooks class to veto events.
#     * The constant Pythia::info member is available as
#       Pythia::infoPython. Note, this creates a new instance of the Info
#       class, and so needs to be called each time the information might be
#       updated.
#
# SUBMODULES
#     std
#
# CLASSES
#     pybind11_builtins.pybind11_object(builtins.object)
#         DecayChannel
#         DecayHandler
#         Event
#         FVec
#         Flag
#         HeavyIons
#         Hist
#         HistPlot
#         Info
#         MVec
#         MergingHooks
#         Mode
#         PDF
#         PVec
#         Parm
#         Particle
#         ParticleData
#         ParticleDataEntry
#         PartonVertex
#         Pythia
#         PythiaParallel
#         Rndm
#         RndmEngine
#         RotBstMatrix
#         Settings
#         SigmaProcess
#         SlowJet
#         SlowJetHook
#         SpaceShower
#         TimeShower
#         UserHooks
#         Vec4
#         WVec
#         Word
#
#     class DecayChannel(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      DecayChannel
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: pythia8.DecayChannel) -> None
#      |
#      |      doc
#      |
#      |      2. __init__(self: pythia8.DecayChannel, onModeIn: int) -> None
#      |
#      |      doc
#      |
#      |      3. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float) -> None
#      |
#      |      doc
#      |
#      |      4. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int) -> None
#      |
#      |      doc
#      |
#      |      5. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int) -> None
#      |
#      |      doc
#      |
#      |      6. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int, prod1: int) -> None
#      |
#      |      doc
#      |
#      |      7. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int, prod1: int, prod2: int) -> None
#      |
#      |      doc
#      |
#      |      8. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int, prod1: int, prod2: int, prod3: int) -> None
#      |
#      |      doc
#      |
#      |      9. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int, prod1: int, prod2: int, prod3: int, prod4: int) -> None
#      |
#      |      doc
#      |
#      |      10. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int, prod1: int, prod2: int, prod3: int, prod4: int, prod5: int) -> None
#      |
#      |      doc
#      |
#      |      11. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int, prod1: int, prod2: int, prod3: int, prod4: int, prod5: int, prod6: int) -> None
#      |
#      |      doc
#      |
#      |      12. __init__(self: pythia8.DecayChannel, onModeIn: int, bRatioIn: float, meModeIn: int, prod0: int, prod1: int, prod2: int, prod3: int, prod4: int, prod5: int, prod6: int, prod7: int) -> None
#      |
#      |      13. __init__(self: pythia8.DecayChannel, arg0: pythia8.DecayChannel) -> None
#      |
#      |  assign(...)
#      |      assign(self: pythia8.DecayChannel, oldDC: pythia8.DecayChannel) -> pythia8.DecayChannel
#      |
#      |      C++: Pythia8::DecayChannel::operator=(const class Pythia8::DecayChannel &) --> class Pythia8::DecayChannel &
#      |
#      |  bRatio(...)
#      |      bRatio(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. bRatio(self: pythia8.DecayChannel, bRatioIn: float) -> None
#      |
#      |      2. bRatio(self: pythia8.DecayChannel, bRatioIn: float, countAsChanged: bool) -> None
#      |
#      |      C++: Pythia8::DecayChannel::bRatio(double, bool) --> void
#      |
#      |      3. bRatio(self: pythia8.DecayChannel) -> float
#      |
#      |      C++: Pythia8::DecayChannel::bRatio() const --> double
#      |
#      |  contains(...)
#      |      contains(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. contains(self: pythia8.DecayChannel, id1: int) -> bool
#      |
#      |      C++: Pythia8::DecayChannel::contains(int) const --> bool
#      |
#      |      2. contains(self: pythia8.DecayChannel, id1: int, id2: int) -> bool
#      |
#      |      C++: Pythia8::DecayChannel::contains(int, int) const --> bool
#      |
#      |      3. contains(self: pythia8.DecayChannel, id1: int, id2: int, id3: int) -> bool
#      |
#      |      C++: Pythia8::DecayChannel::contains(int, int, int) const --> bool
#      |
#      |  currentBR(...)
#      |      currentBR(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. currentBR(self: pythia8.DecayChannel, currentBRIn: float) -> None
#      |
#      |      C++: Pythia8::DecayChannel::currentBR(double) --> void
#      |
#      |      2. currentBR(self: pythia8.DecayChannel) -> float
#      |
#      |      C++: Pythia8::DecayChannel::currentBR() const --> double
#      |
#      |  hasChanged(...)
#      |      hasChanged(self: pythia8.DecayChannel) -> bool
#      |
#      |      C++: Pythia8::DecayChannel::hasChanged() const --> bool
#      |
#      |  meMode(...)
#      |      meMode(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. meMode(self: pythia8.DecayChannel, meModeIn: int) -> None
#      |
#      |      C++: Pythia8::DecayChannel::meMode(int) --> void
#      |
#      |      2. meMode(self: pythia8.DecayChannel) -> int
#      |
#      |      C++: Pythia8::DecayChannel::meMode() const --> int
#      |
#      |  multiplicity(...)
#      |      multiplicity(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. multiplicity(self: pythia8.DecayChannel, multIn: int) -> None
#      |
#      |      C++: Pythia8::DecayChannel::multiplicity(int) --> void
#      |
#      |      2. multiplicity(self: pythia8.DecayChannel) -> int
#      |
#      |      C++: Pythia8::DecayChannel::multiplicity() const --> int
#      |
#      |  onMode(...)
#      |      onMode(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. onMode(self: pythia8.DecayChannel, onModeIn: int) -> None
#      |
#      |      C++: Pythia8::DecayChannel::onMode(int) --> void
#      |
#      |      2. onMode(self: pythia8.DecayChannel) -> int
#      |
#      |      C++: Pythia8::DecayChannel::onMode() const --> int
#      |
#      |  onShellWidth(...)
#      |      onShellWidth(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. onShellWidth(self: pythia8.DecayChannel, onShellWidthIn: float) -> None
#      |
#      |      C++: Pythia8::DecayChannel::onShellWidth(double) --> void
#      |
#      |      2. onShellWidth(self: pythia8.DecayChannel) -> float
#      |
#      |      C++: Pythia8::DecayChannel::onShellWidth() const --> double
#      |
#      |  onShellWidthFactor(...)
#      |      onShellWidthFactor(self: pythia8.DecayChannel, factor: float) -> None
#      |
#      |      C++: Pythia8::DecayChannel::onShellWidthFactor(double) --> void
#      |
#      |  openSec(...)
#      |      openSec(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. openSec(self: pythia8.DecayChannel, idSgn: int, openSecIn: float) -> None
#      |
#      |      C++: Pythia8::DecayChannel::openSec(int, double) --> void
#      |
#      |      2. openSec(self: pythia8.DecayChannel, idSgn: int) -> float
#      |
#      |      C++: Pythia8::DecayChannel::openSec(int) const --> double
#      |
#      |  product(...)
#      |      product(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. product(self: pythia8.DecayChannel, i: int, prodIn: int) -> None
#      |
#      |      C++: Pythia8::DecayChannel::product(int, int) --> void
#      |
#      |      2. product(self: pythia8.DecayChannel, i: int) -> int
#      |
#      |      C++: Pythia8::DecayChannel::product(int) const --> int
#      |
#      |  rescaleBR(...)
#      |      rescaleBR(self: pythia8.DecayChannel, fac: float) -> None
#      |
#      |      C++: Pythia8::DecayChannel::rescaleBR(double) --> void
#      |
#      |  setHasChanged(...)
#      |      setHasChanged(self: pythia8.DecayChannel, hasChangedIn: bool) -> None
#      |
#      |      C++: Pythia8::DecayChannel::setHasChanged(bool) --> void
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class DecayHandler(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      DecayHandler
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: pythia8.DecayHandler) -> None
#      |
#      |  assign(...)
#      |      assign(self: pythia8.DecayHandler, : pythia8.DecayHandler) -> pythia8.DecayHandler
#      |
#      |      C++: Pythia8::DecayHandler::operator=(const class Pythia8::DecayHandler &) --> class Pythia8::DecayHandler &
#      |
#      |  chainDecay(...)
#      |      chainDecay(self: pythia8.DecayHandler, : List[int], : List[int], : List[float], : List[pythia8.Vec4], : int, : pythia8.Event) -> bool
#      |
#      |      C++: Pythia8::DecayHandler::chainDecay(class std::vector<int, class std::allocator<int> > &, class std::vector<int, class std::allocator<int> > &, class std::vector<double, class std::allocator<double> > &, class std::vector<class Pythia8::Vec4, class std::allocator<class Pythia8::Vec4> > &, int, const class Pythia8::Event &) --> bool
#      |
#      |  decay(...)
#      |      decay(self: pythia8.DecayHandler, : List[int], : List[float], : List[pythia8.Vec4], : int, : pythia8.Event) -> bool
#      |
#      |      C++: Pythia8::DecayHandler::decay(class std::vector<int, class std::allocator<int> > &, class std::vector<double, class std::allocator<double> > &, class std::vector<class Pythia8::Vec4, class std::allocator<class Pythia8::Vec4> > &, int, const class Pythia8::Event &) --> bool
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class Event(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      Event
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  REtaPhi(...)
#      |      REtaPhi(self: pythia8.Event, i1: int, i2: int) -> float
#      |
#      |      C++: Pythia8::Event::REtaPhi(int, int) const --> double
#      |
#      |  RRapPhi(...)
#      |      RRapPhi(self: pythia8.Event, i1: int, i2: int) -> float
#      |
#      |      C++: Pythia8::Event::RRapPhi(int, int) const --> double
#      |
#      |  __getitem__(...)
#      |      __getitem__(self: pythia8.Event, i: int) -> pythia8.Particle
#      |
#      |      C++: Pythia8::Event::operator[](int) --> class Pythia8::Particle &
#      |
#      |  __iadd__(...)
#      |      __iadd__(self: pythia8.Event, addEvent: pythia8.Event) -> pythia8.Event
#      |
#      |      C++: Pythia8::Event::operator+=(const class Pythia8::Event &) --> class Pythia8::Event &
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: pythia8.Event) -> None
#      |
#      |      doc
#      |
#      |      2. __init__(self: pythia8.Event, capacity: int) -> None
#      |
#      |      3. __init__(self: pythia8.Event, arg0: pythia8.Event) -> None
#      |
#      |  append(...)
#      |      append(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. append(self: pythia8.Event, entryIn: pythia8.Particle) -> int
#      |
#      |      C++: Pythia8::Event::append(class Pythia8::Particle) --> int
#      |
#      |      2. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, px: float, py: float, pz: float, e: float) -> int
#      |
#      |      3. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, px: float, py: float, pz: float, e: float, m: float) -> int
#      |
#      |      4. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, px: float, py: float, pz: float, e: float, m: float, scaleIn: float) -> int
#      |
#      |      5. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, px: float, py: float, pz: float, e: float, m: float, scaleIn: float, polIn: float) -> int
#      |
#      |      C++: Pythia8::Event::append(int, int, int, int, int, int, int, int, double, double, double, double, double, double, double) --> int
#      |
#      |      6. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, p: pythia8.Vec4) -> int
#      |
#      |      7. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, p: pythia8.Vec4, m: float) -> int
#      |
#      |      8. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, p: pythia8.Vec4, m: float, scaleIn: float) -> int
#      |
#      |      9. append(self: pythia8.Event, id: int, status: int, mother1: int, mother2: int, daughter1: int, daughter2: int, col: int, acol: int, p: pythia8.Vec4, m: float, scaleIn: float, polIn: float) -> int
#      |
#      |      C++: Pythia8::Event::append(int, int, int, int, int, int, int, int, class Pythia8::Vec4, double, double, double) --> int
#      |
#      |      10. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, px: float, py: float, pz: float, e: float) -> int
#      |
#      |      11. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, px: float, py: float, pz: float, e: float, m: float) -> int
#      |
#      |      12. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, px: float, py: float, pz: float, e: float, m: float, scaleIn: float) -> int
#      |
#      |      13. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, px: float, py: float, pz: float, e: float, m: float, scaleIn: float, polIn: float) -> int
#      |
#      |      C++: Pythia8::Event::append(int, int, int, int, double, double, double, double, double, double, double) --> int
#      |
#      |      14. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, p: pythia8.Vec4) -> int
#      |
#      |      15. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, p: pythia8.Vec4, m: float) -> int
#      |
#      |      16. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, p: pythia8.Vec4, m: float, scaleIn: float) -> int
#      |
#      |      17. append(self: pythia8.Event, id: int, status: int, col: int, acol: int, p: pythia8.Vec4, m: float, scaleIn: float, polIn: float) -> int
#      |
#      |      C++: Pythia8::Event::append(int, int, int, int, class Pythia8::Vec4, double, double, double) --> int
#      |
#      |  appendJunction(...)
#      |      appendJunction(self: pythia8.Event, kind: int, col0: int, col1: int, col2: int) -> int
#      |
#      |      C++: Pythia8::Event::appendJunction(int, int, int, int) --> int
#      |
#      |  assign(...)
#      |      assign(self: pythia8.Event, oldEvent: pythia8.Event) -> pythia8.Event
#      |
#      |      C++: Pythia8::Event::operator=(const class Pythia8::Event &) --> class Pythia8::Event &
#      |
#      |  at(...)
#      |      at(self: pythia8.Event, i: int) -> pythia8.Particle
#      |
#      |      C++: Pythia8::Event::at(int) --> class Pythia8::Particle &
#      |
#      |  back(...)
#      |      back(self: pythia8.Event) -> pythia8.Particle
#      |
#      |      C++: Pythia8::Event::back() --> class Pythia8::Particle &
#      |
#      |  bst(...)
#      |      bst(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. bst(self: pythia8.Event, betaX: float, betaY: float, betaZ: float) -> None
#      |
#      |      C++: Pythia8::Event::bst(double, double, double) --> void
#      |
#      |      2. bst(self: pythia8.Event, betaX: float, betaY: float, betaZ: float, gamma: float) -> None
#      |
#      |      C++: Pythia8::Event::bst(double, double, double, double) --> void
#      |
#      |      3. bst(self: pythia8.Event, vec: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Event::bst(const class Pythia8::Vec4 &) --> void
#      |
#      |  clear(...)
#      |      clear(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::clear() --> void
#      |
#      |  clearJunctions(...)
#      |      clearJunctions(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::clearJunctions() --> void
#      |
#      |  colJunction(...)
#      |      colJunction(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. colJunction(self: pythia8.Event, i: int, j: int) -> int
#      |
#      |      C++: Pythia8::Event::colJunction(int, int) const --> int
#      |
#      |      2. colJunction(self: pythia8.Event, i: int, j: int, colIn: int) -> None
#      |
#      |      C++: Pythia8::Event::colJunction(int, int, int) --> void
#      |
#      |  copy(...)
#      |      copy(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. copy(self: pythia8.Event, iCopy: int) -> int
#      |
#      |      2. copy(self: pythia8.Event, iCopy: int, newStatus: int) -> int
#      |
#      |      C++: Pythia8::Event::copy(int, int) --> int
#      |
#      |  daughterList(...)
#      |      daughterList(self: pythia8.Event, i: int) -> List[int]
#      |
#      |      C++: Pythia8::Event::daughterList(int) const --> class std::vector<int, class std::allocator<int> >
#      |
#      |  detaAbs(...)
#      |      detaAbs(self: pythia8.Event, i1: int, i2: int) -> float
#      |
#      |      C++: Pythia8::Event::detaAbs(int, int) const --> double
#      |
#      |  dphiAbs(...)
#      |      dphiAbs(self: pythia8.Event, i1: int, i2: int) -> float
#      |
#      |      C++: Pythia8::Event::dphiAbs(int, int) const --> double
#      |
#      |  dyAbs(...)
#      |      dyAbs(self: pythia8.Event, i1: int, i2: int) -> float
#      |
#      |      C++: Pythia8::Event::dyAbs(int, int) const --> double
#      |
#      |  endColJunction(...)
#      |      endColJunction(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. endColJunction(self: pythia8.Event, i: int, j: int) -> int
#      |
#      |      C++: Pythia8::Event::endColJunction(int, int) const --> int
#      |
#      |      2. endColJunction(self: pythia8.Event, i: int, j: int, endColIn: int) -> None
#      |
#      |      C++: Pythia8::Event::endColJunction(int, int, int) --> void
#      |
#      |  eraseJunction(...)
#      |      eraseJunction(self: pythia8.Event, i: int) -> None
#      |
#      |      C++: Pythia8::Event::eraseJunction(int) --> void
#      |
#      |  free(...)
#      |      free(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::free() --> void
#      |
#      |  front(...)
#      |      front(self: pythia8.Event) -> pythia8.Particle
#      |
#      |      C++: Pythia8::Event::front() --> class Pythia8::Particle &
#      |
#      |  hasHVcols(...)
#      |      hasHVcols(self: pythia8.Event) -> bool
#      |
#      |      C++: Pythia8::Event::hasHVcols() const --> bool
#      |
#      |  init(...)
#      |      init(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. init(self: pythia8.Event) -> None
#      |
#      |      2. init(self: pythia8.Event, headerIn: str) -> None
#      |
#      |      3. init(self: pythia8.Event, headerIn: str, particleDataPtrIn: pythia8.ParticleData) -> None
#      |
#      |      4. init(self: pythia8.Event, headerIn: str, particleDataPtrIn: pythia8.ParticleData, startColTagIn: int) -> None
#      |
#      |      C++: Pythia8::Event::init(std::string, class Pythia8::ParticleData *, int) --> void
#      |
#      |  initColTag(...)
#      |      initColTag(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. initColTag(self: pythia8.Event) -> None
#      |
#      |      2. initColTag(self: pythia8.Event, colTag: int) -> None
#      |
#      |      C++: Pythia8::Event::initColTag(int) --> void
#      |
#      |  kindJunction(...)
#      |      kindJunction(self: pythia8.Event, i: int) -> int
#      |
#      |      C++: Pythia8::Event::kindJunction(int) const --> int
#      |
#      |  lastColTag(...)
#      |      lastColTag(self: pythia8.Event) -> int
#      |
#      |      C++: Pythia8::Event::lastColTag() const --> int
#      |
#      |  list(...)
#      |      list(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. list(self: pythia8.Event) -> None
#      |
#      |      2. list(self: pythia8.Event, showScaleAndVertex: bool) -> None
#      |
#      |      3. list(self: pythia8.Event, showScaleAndVertex: bool, showMothersAndDaughters: bool) -> None
#      |
#      |      4. list(self: pythia8.Event, showScaleAndVertex: bool, showMothersAndDaughters: bool, precision: int) -> None
#      |
#      |      C++: Pythia8::Event::list(bool, bool, int) const --> void
#      |
#      |  listHVcols(...)
#      |      listHVcols(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::listHVcols() const --> void
#      |
#      |  listJunctions(...)
#      |      listJunctions(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::listJunctions() const --> void
#      |
#      |  maxHVcols(...)
#      |      maxHVcols(self: pythia8.Event) -> int
#      |
#      |      C++: Pythia8::Event::maxHVcols() const --> int
#      |
#      |  nFinal(...)
#      |      nFinal(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. nFinal(self: pythia8.Event) -> int
#      |
#      |      2. nFinal(self: pythia8.Event, chargedOnly: bool) -> int
#      |
#      |      C++: Pythia8::Event::nFinal(bool) const --> int
#      |
#      |  nextColTag(...)
#      |      nextColTag(self: pythia8.Event) -> int
#      |
#      |      C++: Pythia8::Event::nextColTag() --> int
#      |
#      |  popBack(...)
#      |      popBack(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. popBack(self: pythia8.Event) -> None
#      |
#      |      2. popBack(self: pythia8.Event, nRemove: int) -> None
#      |
#      |      C++: Pythia8::Event::popBack(int) --> void
#      |
#      |  remainsJunction(...)
#      |      remainsJunction(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. remainsJunction(self: pythia8.Event, i: int) -> bool
#      |
#      |      C++: Pythia8::Event::remainsJunction(int) const --> bool
#      |
#      |      2. remainsJunction(self: pythia8.Event, i: int, remainsIn: bool) -> None
#      |
#      |      C++: Pythia8::Event::remainsJunction(int, bool) --> void
#      |
#      |  remove(...)
#      |      remove(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. remove(self: pythia8.Event, iFirst: int, iLast: int) -> None
#      |
#      |      2. remove(self: pythia8.Event, iFirst: int, iLast: int, shiftHistory: bool) -> None
#      |
#      |      C++: Pythia8::Event::remove(int, int, bool) --> void
#      |
#      |  reset(...)
#      |      reset(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::reset() --> void
#      |
#      |  restoreHVcolsSize(...)
#      |      restoreHVcolsSize(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::restoreHVcolsSize() --> void
#      |
#      |  restoreJunctionSize(...)
#      |      restoreJunctionSize(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::restoreJunctionSize() --> void
#      |
#      |  restorePtrs(...)
#      |      restorePtrs(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::restorePtrs() --> void
#      |
#      |  restoreSize(...)
#      |      restoreSize(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::restoreSize() --> void
#      |
#      |  rot(...)
#      |      rot(self: pythia8.Event, theta: float, phi: float) -> None
#      |
#      |      C++: Pythia8::Event::rot(double, double) --> void
#      |
#      |  rotbst(...)
#      |      rotbst(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. rotbst(self: pythia8.Event, M: pythia8.RotBstMatrix) -> None
#      |
#      |      2. rotbst(self: pythia8.Event, M: pythia8.RotBstMatrix, boostVertices: bool) -> None
#      |
#      |      C++: Pythia8::Event::rotbst(const class Pythia8::RotBstMatrix &, bool) --> void
#      |
#      |  saveHVcolsSize(...)
#      |      saveHVcolsSize(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::saveHVcolsSize() --> void
#      |
#      |  saveJunctionSize(...)
#      |      saveJunctionSize(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::saveJunctionSize() --> void
#      |
#      |  savePartonLevelSize(...)
#      |      savePartonLevelSize(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::savePartonLevelSize() --> void
#      |
#      |  saveSize(...)
#      |      saveSize(self: pythia8.Event) -> None
#      |
#      |      C++: Pythia8::Event::saveSize() --> void
#      |
#      |  savedSizeValue(...)
#      |      savedSizeValue(self: pythia8.Event) -> int
#      |
#      |      C++: Pythia8::Event::savedSizeValue() --> int
#      |
#      |  scale(...)
#      |      scale(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. scale(self: pythia8.Event, scaleIn: float) -> None
#      |
#      |      C++: Pythia8::Event::scale(double) --> void
#      |
#      |      2. scale(self: pythia8.Event) -> float
#      |
#      |      C++: Pythia8::Event::scale() const --> double
#      |
#      |  scaleSecond(...)
#      |      scaleSecond(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. scaleSecond(self: pythia8.Event, scaleSecondIn: float) -> None
#      |
#      |      C++: Pythia8::Event::scaleSecond(double) --> void
#      |
#      |      2. scaleSecond(self: pythia8.Event) -> float
#      |
#      |      C++: Pythia8::Event::scaleSecond() const --> double
#      |
#      |  setEvtPtr(...)
#      |      setEvtPtr(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. setEvtPtr(self: pythia8.Event) -> None
#      |
#      |      2. setEvtPtr(self: pythia8.Event, iSet: int) -> None
#      |
#      |      C++: Pythia8::Event::setEvtPtr(int) --> void
#      |
#      |  size(...)
#      |      size(self: pythia8.Event) -> int
#      |
#      |      C++: Pythia8::Event::size() const --> int
#      |
#      |  sizeJunction(...)
#      |      sizeJunction(self: pythia8.Event) -> int
#      |
#      |      C++: Pythia8::Event::sizeJunction() const --> int
#      |
#      |  statusJunction(...)
#      |      statusJunction(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. statusJunction(self: pythia8.Event, i: int, j: int) -> int
#      |
#      |      C++: Pythia8::Event::statusJunction(int, int) const --> int
#      |
#      |      2. statusJunction(self: pythia8.Event, i: int, j: int, statusIn: int) -> None
#      |
#      |      C++: Pythia8::Event::statusJunction(int, int, int) --> void
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class FVec(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      FVec
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: pythia8.FVec) -> None
#      |
#      |      doc
#      |
#      |      2. __init__(self: pythia8.FVec, nameIn: str) -> None
#      |
#      |      doc
#      |
#      |      3. __init__(self: pythia8.FVec, nameIn: str, defaultIn: List[bool]) -> None
#      |
#      |      4. __init__(self: pythia8.FVec, arg0: pythia8.FVec) -> None
#      |
#      |  assign(...)
#      |      assign(self: pythia8.FVec, : pythia8.FVec) -> pythia8.FVec
#      |
#      |      C++: Pythia8::FVec::operator=(const class Pythia8::FVec &) --> class Pythia8::FVec &
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  name
#      |
#      |  valDefault
#      |
#      |  valNow
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class Flag(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      Flag
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: pythia8.Flag) -> None
#      |
#      |      doc
#      |
#      |      2. __init__(self: pythia8.Flag, nameIn: str) -> None
#      |
#      |      doc
#      |
#      |      3. __init__(self: pythia8.Flag, nameIn: str, defaultIn: bool) -> None
#      |
#      |      4. __init__(self: pythia8.Flag, arg0: pythia8.Flag) -> None
#      |
#      |  assign(...)
#      |      assign(self: pythia8.Flag, : pythia8.Flag) -> pythia8.Flag
#      |
#      |      C++: Pythia8::Flag::operator=(const class Pythia8::Flag &) --> class Pythia8::Flag &
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  name
#      |
#      |  valDefault
#      |
#      |  valNow
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class HeavyIons(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      HeavyIons
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(self: pythia8.HeavyIons, mainPythiaIn: pythia8.Pythia) -> None
#      |
#      |  assign(...)
#      |      assign(self: pythia8.HeavyIons, : pythia8.HeavyIons) -> pythia8.HeavyIons
#      |
#      |      C++: Pythia8::HeavyIons::operator=(const class Pythia8::HeavyIons &) --> class Pythia8::HeavyIons &
#      |
#      |  clearProcessLevel(...)
#      |      clearProcessLevel(self: pythia8.HeavyIons, pyt: pythia8.Pythia) -> None
#      |
#      |      C++: Pythia8::HeavyIons::clearProcessLevel(class Pythia8::Pythia &) --> void
#      |
#      |  init(...)
#      |      init(self: pythia8.HeavyIons) -> bool
#      |
#      |      C++: Pythia8::HeavyIons::init() --> bool
#      |
#      |  next(...)
#      |      next(self: pythia8.HeavyIons) -> bool
#      |
#      |      C++: Pythia8::HeavyIons::next() --> bool
#      |
#      |  setHIUserHooksPtr(...)
#      |      setHIUserHooksPtr(self: pythia8.HeavyIons, userHooksPtrIn: Pythia8::HIUserHooks) -> bool
#      |
#      |      C++: Pythia8::HeavyIons::setHIUserHooksPtr(class std::shared_ptr<class Pythia8::HIUserHooks>) --> bool
#      |
#      |  stat(...)
#      |      stat(self: pythia8.HeavyIons) -> None
#      |
#      |      C++: Pythia8::HeavyIons::stat() --> void
#      |
#      |  sumUpMessages(...)
#      |      sumUpMessages(self: pythia8.HeavyIons, in: pythia8.Info, tag: str, other: pythia8.Info) -> None
#      |
#      |      C++: Pythia8::HeavyIons::sumUpMessages(class Pythia8::Info &, std::string, const class Pythia8::Info *) --> void
#      |
#      |  updateInfo(...)
#      |      updateInfo(self: pythia8.HeavyIons) -> None
#      |
#      |      C++: Pythia8::HeavyIons::updateInfo() --> void
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods defined here:
#      |
#      |  addSpecialSettings(...) from builtins.PyCapsule
#      |      addSpecialSettings(settings: pythia8.Settings) -> None
#      |
#      |      C++: Pythia8::HeavyIons::addSpecialSettings(class Pythia8::Settings &) --> void
#      |
#      |  isHeavyIon(...) from builtins.PyCapsule
#      |      isHeavyIon(settings: pythia8.Settings) -> bool
#      |
#      |      C++: Pythia8::HeavyIons::isHeavyIon(class Pythia8::Settings &) --> bool
#      |
#      |  setupSpecials(...) from builtins.PyCapsule
#      |      setupSpecials(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. setupSpecials(settings: pythia8.Settings, match: str) -> None
#      |
#      |      C++: Pythia8::HeavyIons::setupSpecials(class Pythia8::Settings &, std::string) --> void
#      |
#      |      2. setupSpecials(p: pythia8.Pythia, match: str) -> None
#      |
#      |      C++: Pythia8::HeavyIons::setupSpecials(class Pythia8::Pythia &, std::string) --> void
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  HIHooksPtr
#      |
#      |  hiInfo
#      |
#      |  info
#      |
#      |  pythia
#      |
#      |  pythiaNames
#      |
#      |  sigtot
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  InfoGrabber = <class 'pythia8.HeavyIons.InfoGrabber'>
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class Hist(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      Hist
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(...)
#      |      __add__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __add__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator+(double) const --> class Pythia8::Hist
#      |
#      |      2. __add__(self: pythia8.Hist, h2: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator+(const class Pythia8::Hist &) const --> class Pythia8::Hist
#      |
#      |  __div__(...)
#      |      __div__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __div__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator/(double) const --> class Pythia8::Hist
#      |
#      |      2. __div__(self: pythia8.Hist, h2: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator/(const class Pythia8::Hist &) const --> class Pythia8::Hist
#      |
#      |  __iadd__(...)
#      |      __iadd__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __iadd__(self: pythia8.Hist, h: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator+=(const class Pythia8::Hist &) --> class Pythia8::Hist &
#      |
#      |      2. __iadd__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator+=(double) --> class Pythia8::Hist &
#      |
#      |  __idiv__(...)
#      |      __idiv__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __idiv__(self: pythia8.Hist, h: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator/=(const class Pythia8::Hist &) --> class Pythia8::Hist &
#      |
#      |      2. __idiv__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator/=(double) --> class Pythia8::Hist &
#      |
#      |  __imul__(...)
#      |      __imul__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __imul__(self: pythia8.Hist, h: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator*=(const class Pythia8::Hist &) --> class Pythia8::Hist &
#      |
#      |      2. __imul__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator*=(double) --> class Pythia8::Hist &
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: pythia8.Hist) -> None
#      |
#      |      2. __init__(self: pythia8.Hist, titleIn: str) -> None
#      |
#      |      doc
#      |
#      |      3. __init__(self: pythia8.Hist, titleIn: str, nBinIn: int) -> None
#      |
#      |      doc
#      |
#      |      4. __init__(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float) -> None
#      |
#      |      doc
#      |
#      |      5. __init__(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float, xMaxIn: float) -> None
#      |
#      |      doc
#      |
#      |      6. __init__(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float, xMaxIn: float, logXIn: bool) -> None
#      |
#      |      doc
#      |
#      |      7. __init__(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float, xMaxIn: float, logXIn: bool, doStatsIn: bool) -> None
#      |
#      |      8. __init__(self: pythia8.Hist, arg0: pythia8.Hist) -> None
#      |
#      |      9. __init__(self: pythia8.Hist, titleIn: str, h: pythia8.Hist) -> None
#      |
#      |  __isub__(...)
#      |      __isub__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __isub__(self: pythia8.Hist, h: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator-=(const class Pythia8::Hist &) --> class Pythia8::Hist &
#      |
#      |      2. __isub__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator-=(double) --> class Pythia8::Hist &
#      |
#      |  __mul__(...)
#      |      __mul__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __mul__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator*(double) const --> class Pythia8::Hist
#      |
#      |      2. __mul__(self: pythia8.Hist, h2: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator*(const class Pythia8::Hist &) const --> class Pythia8::Hist
#      |
#      |  __str__(...)
#      |      __str__(self: pythia8.Hist) -> str
#      |
#      |  __sub__(...)
#      |      __sub__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __sub__(self: pythia8.Hist, f: float) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator-(double) const --> class Pythia8::Hist
#      |
#      |      2. __sub__(self: pythia8.Hist, h2: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator-(const class Pythia8::Hist &) const --> class Pythia8::Hist
#      |
#      |  assign(...)
#      |      assign(self: pythia8.Hist, h: pythia8.Hist) -> pythia8.Hist
#      |
#      |      C++: Pythia8::Hist::operator=(const class Pythia8::Hist &) --> class Pythia8::Hist &
#      |
#      |  book(...)
#      |      book(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. book(self: pythia8.Hist) -> None
#      |
#      |      2. book(self: pythia8.Hist, titleIn: str) -> None
#      |
#      |      3. book(self: pythia8.Hist, titleIn: str, nBinIn: int) -> None
#      |
#      |      4. book(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float) -> None
#      |
#      |      5. book(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float, xMaxIn: float) -> None
#      |
#      |      6. book(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float, xMaxIn: float, logXIn: bool) -> None
#      |
#      |      7. book(self: pythia8.Hist, titleIn: str, nBinIn: int, xMinIn: float, xMaxIn: float, logXIn: bool, doStatsIn: bool) -> None
#      |
#      |      C++: Pythia8::Hist::book(std::string, int, double, double, bool, bool) --> void
#      |
#      |  fill(...)
#      |      fill(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. fill(self: pythia8.Hist, x: float) -> None
#      |
#      |      2. fill(self: pythia8.Hist, x: float, w: float) -> None
#      |
#      |      C++: Pythia8::Hist::fill(double, double) --> void
#      |
#      |  fillTable(...)
#      |      fillTable(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. fillTable(self: pythia8.Hist) -> None
#      |
#      |      2. fillTable(self: pythia8.Hist, is: std::__1::basic_istream<char, std::__1::char_traits<char>>) -> None
#      |
#      |      C++: Pythia8::Hist::fillTable(class std::basic_istream<char> &) --> void
#      |
#      |      3. fillTable(self: pythia8.Hist, fileName: str) -> None
#      |
#      |      C++: Pythia8::Hist::fillTable(std::string) --> void
#      |
#      |  getBinContent(...)
#      |      getBinContent(self: pythia8.Hist, iBin: int) -> float
#      |
#      |      C++: Pythia8::Hist::getBinContent(int) const --> double
#      |
#      |  getBinContents(...)
#      |      getBinContents(self: pythia8.Hist) -> List[float]
#      |
#      |      C++: Pythia8::Hist::getBinContents() const --> class std::vector<double, class std::allocator<double> >
#      |
#      |  getBinEdge(...)
#      |      getBinEdge(self: pythia8.Hist, iBin: int) -> float
#      |
#      |      C++: Pythia8::Hist::getBinEdge(int) const --> double
#      |
#      |  getBinEdges(...)
#      |      getBinEdges(self: pythia8.Hist) -> List[float]
#      |
#      |      C++: Pythia8::Hist::getBinEdges() const --> class std::vector<double, class std::allocator<double> >
#      |
#      |  getBinNumber(...)
#      |      getBinNumber(self: pythia8.Hist) -> int
#      |
# ...
#      |
#      |  __sub__(...)
#      |      __sub__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __sub__(self: pythia8.Vec4) -> pythia8.Vec4
#      |
#      |      C++: Pythia8::Vec4::operator-() const --> class Pythia8::Vec4
#      |
#      |      2. __sub__(self: pythia8.Vec4, v: pythia8.Vec4) -> pythia8.Vec4
#      |
#      |      C++: Pythia8::Vec4::operator-(const class Pythia8::Vec4 &) const --> class Pythia8::Vec4
#      |
#      |  assign(...)
#      |      assign(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. assign(self: pythia8.Vec4, v: pythia8.Vec4) -> pythia8.Vec4
#      |
#      |      C++: Pythia8::Vec4::operator=(const class Pythia8::Vec4 &) --> class Pythia8::Vec4 &
#      |
#      |      2. assign(self: pythia8.Vec4, value: float) -> pythia8.Vec4
#      |
#      |      C++: Pythia8::Vec4::operator=(double) --> class Pythia8::Vec4 &
#      |
#      |  bst(...)
#      |      bst(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. bst(self: pythia8.Vec4, betaX: float, betaY: float, betaZ: float) -> None
#      |
#      |      C++: Pythia8::Vec4::bst(double, double, double) --> void
#      |
#      |      2. bst(self: pythia8.Vec4, betaX: float, betaY: float, betaZ: float, gamma: float) -> None
#      |
#      |      C++: Pythia8::Vec4::bst(double, double, double, double) --> void
#      |
#      |      3. bst(self: pythia8.Vec4, pIn: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Vec4::bst(const class Pythia8::Vec4 &) --> void
#      |
#      |      4. bst(self: pythia8.Vec4, pIn: pythia8.Vec4, mIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::bst(const class Pythia8::Vec4 &, double) --> void
#      |
#      |  bstback(...)
#      |      bstback(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. bstback(self: pythia8.Vec4, pIn: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Vec4::bstback(const class Pythia8::Vec4 &) --> void
#      |
#      |      2. bstback(self: pythia8.Vec4, pIn: pythia8.Vec4, mIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::bstback(const class Pythia8::Vec4 &, double) --> void
#      |
#      |  e(...)
#      |      e(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. e(self: pythia8.Vec4, tIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::e(double) --> void
#      |
#      |      2. e(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::e() const --> double
#      |
#      |  eT(...)
#      |      eT(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::eT() const --> double
#      |
#      |  eT2(...)
#      |      eT2(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::eT2() const --> double
#      |
#      |  eta(...)
#      |      eta(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::eta() const --> double
#      |
#      |  flip3(...)
#      |      flip3(self: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Vec4::flip3() --> void
#      |
#      |  flip4(...)
#      |      flip4(self: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Vec4::flip4() --> void
#      |
#      |  m2Calc(...)
#      |      m2Calc(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::m2Calc() const --> double
#      |
#      |  mCalc(...)
#      |      mCalc(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::mCalc() const --> double
#      |
#      |  p(...)
#      |      p(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. p(self: pythia8.Vec4, xIn: float, yIn: float, zIn: float, tIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::p(double, double, double, double) --> void
#      |
#      |      2. p(self: pythia8.Vec4, pIn: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Vec4::p(class Pythia8::Vec4) --> void
#      |
#      |  pAbs(...)
#      |      pAbs(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::pAbs() const --> double
#      |
#      |  pAbs2(...)
#      |      pAbs2(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::pAbs2() const --> double
#      |
#      |  pNeg(...)
#      |      pNeg(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::pNeg() const --> double
#      |
#      |  pPos(...)
#      |      pPos(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::pPos() const --> double
#      |
#      |  pT(...)
#      |      pT(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::pT() const --> double
#      |
#      |  pT2(...)
#      |      pT2(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::pT2() const --> double
#      |
#      |  phi(...)
#      |      phi(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::phi() const --> double
#      |
#      |  px(...)
#      |      px(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. px(self: pythia8.Vec4, xIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::px(double) --> void
#      |
#      |      2. px(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::px() const --> double
#      |
#      |  py(...)
#      |      py(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. py(self: pythia8.Vec4, yIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::py(double) --> void
#      |
#      |      2. py(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::py() const --> double
#      |
#      |  pz(...)
#      |      pz(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. pz(self: pythia8.Vec4, zIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::pz(double) --> void
#      |
#      |      2. pz(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::pz() const --> double
#      |
#      |  rap(...)
#      |      rap(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::rap() const --> double
#      |
#      |  rescale3(...)
#      |      rescale3(self: pythia8.Vec4, fac: float) -> None
#      |
#      |      C++: Pythia8::Vec4::rescale3(double) --> void
#      |
#      |  rescale4(...)
#      |      rescale4(self: pythia8.Vec4, fac: float) -> None
#      |
#      |      C++: Pythia8::Vec4::rescale4(double) --> void
#      |
#      |  reset(...)
#      |      reset(self: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Vec4::reset() --> void
#      |
#      |  rot(...)
#      |      rot(self: pythia8.Vec4, thetaIn: float, phiIn: float) -> None
#      |
#      |      C++: Pythia8::Vec4::rot(double, double) --> void
#      |
#      |  rotaxis(...)
#      |      rotaxis(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. rotaxis(self: pythia8.Vec4, phiIn: float, nx: float, ny: float, nz: float) -> None
#      |
#      |      C++: Pythia8::Vec4::rotaxis(double, double, double, double) --> void
#      |
#      |      2. rotaxis(self: pythia8.Vec4, phiIn: float, n: pythia8.Vec4) -> None
#      |
#      |      C++: Pythia8::Vec4::rotaxis(double, const class Pythia8::Vec4 &) --> void
#      |
#      |  rotbst(...)
#      |      rotbst(self: pythia8.Vec4, M: Pythia8::RotBstMatrix) -> None
#      |
#      |      C++: Pythia8::Vec4::rotbst(const class Pythia8::RotBstMatrix &) --> void
#      |
#      |  theta(...)
#      |      theta(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::theta() const --> double
#      |
#      |  thetaXZ(...)
#      |      thetaXZ(self: pythia8.Vec4) -> float
#      |
#      |      C++: Pythia8::Vec4::thetaXZ() const --> double
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class WVec(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      WVec
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: pythia8.WVec) -> None
#      |
#      |      doc
#      |
#      |      2. __init__(self: pythia8.WVec, nameIn: str) -> None
#      |
#      |      doc
#      |
#      |      3. __init__(self: pythia8.WVec, nameIn: str, defaultIn: List[str]) -> None
#      |
#      |      4. __init__(self: pythia8.WVec, arg0: pythia8.WVec) -> None
#      |
#      |  assign(...)
#      |      assign(self: pythia8.WVec, : pythia8.WVec) -> pythia8.WVec
#      |
#      |      C++: Pythia8::WVec::operator=(const class Pythia8::WVec &) --> class Pythia8::WVec &
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  name
#      |
#      |  valDefault
#      |
#      |  valNow
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
#     class Word(pybind11_builtins.pybind11_object)
#      |  Method resolution order:
#      |      Word
#      |      pybind11_builtins.pybind11_object
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      __init__(*args, **kwargs)
#      |      Overloaded function.
#      |
#      |      1. __init__(self: pythia8.Word) -> None
#      |
#      |      doc
#      |
#      |      2. __init__(self: pythia8.Word, nameIn: str) -> None
#      |
#      |      doc
#      |
#      |      3. __init__(self: pythia8.Word, nameIn: str, defaultIn: str) -> None
#      |
#      |      4. __init__(self: pythia8.Word, arg0: pythia8.Word) -> None
#      |
#      |  assign(...)
#      |      assign(self: pythia8.Word, : pythia8.Word) -> pythia8.Word
#      |
#      |      C++: Pythia8::Word::operator=(const class Pythia8::Word &) --> class Pythia8::Word &
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  name
#      |
#      |  valDefault
#      |
#      |  valNow
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from pybind11_builtins.pybind11_object:
#      |
#      |  __new__(*args, **kwargs) from pybind11_builtins.pybind11_type
#      |      Create and return a new object.  See help(type) for accurate signature.
#
# FUNCTIONS
#     REtaPhi(...) method of builtins.PyCapsule instance
#         REtaPhi(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::REtaPhi(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#     RRapPhi(...) method of builtins.PyCapsule instance
#         RRapPhi(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::RRapPhi(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#     cosphi(...) method of builtins.PyCapsule instance
#         cosphi(*args, **kwargs)
#         Overloaded function.
#
#         1. cosphi(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::cosphi(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#         2. cosphi(v1: pythia8.Vec4, v2: pythia8.Vec4, n: pythia8.Vec4) -> float
#
#         C++: Pythia8::cosphi(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#     costheta(...) method of builtins.PyCapsule instance
#         costheta(*args, **kwargs)
#         Overloaded function.
#
#         1. costheta(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::costheta(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#         2. costheta(e1: float, e2: float, m1: float, m2: float, s12: float) -> float
#
#         C++: Pythia8::costheta(double, double, double, double, double) --> double
#
#     cross3(...) method of builtins.PyCapsule instance
#         cross3(v1: pythia8.Vec4, v2: pythia8.Vec4) -> pythia8.Vec4
#
#         C++: Pythia8::cross3(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> class Pythia8::Vec4
#
#     cross4(...) method of builtins.PyCapsule instance
#         cross4(a: pythia8.Vec4, b: pythia8.Vec4, c: pythia8.Vec4) -> pythia8.Vec4
#
#         C++: Pythia8::cross4(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> class Pythia8::Vec4
#
#     dot3(...) method of builtins.PyCapsule instance
#         dot3(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::dot3(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#     m(...) method of builtins.PyCapsule instance
#         m(*args, **kwargs)
#         Overloaded function.
#
#         1. m(v1: pythia8.Vec4) -> float
#
#         C++: Pythia8::m(const class Pythia8::Vec4 &) --> double
#
#         2. m(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::m(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#         3. m(pp1: pythia8.Particle, pp2: pythia8.Particle) -> float
#
#         C++: Pythia8::m(const class Pythia8::Particle &, const class Pythia8::Particle &) --> double
#
#     m2(...) method of builtins.PyCapsule instance
#         m2(*args, **kwargs)
#         Overloaded function.
#
#         1. m2(v1: pythia8.Vec4) -> float
#
#         C++: Pythia8::m2(const class Pythia8::Vec4 &) --> double
#
#         2. m2(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::m2(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#         3. m2(v1: pythia8.Vec4, v2: pythia8.Vec4, v3: pythia8.Vec4) -> float
#
#         C++: Pythia8::m2(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#         4. m2(v1: pythia8.Vec4, v2: pythia8.Vec4, v3: pythia8.Vec4, v4: pythia8.Vec4) -> float
#
#         C++: Pythia8::m2(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &, const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#         5. m2(pp1: pythia8.Particle, pp2: pythia8.Particle) -> float
#
#         C++: Pythia8::m2(const class Pythia8::Particle &, const class Pythia8::Particle &) --> double
#
#         6. m2(pp1: pythia8.Particle, pp2: pythia8.Particle, pp3: pythia8.Particle) -> float
#
#         C++: Pythia8::m2(const class Pythia8::Particle &, const class Pythia8::Particle &, const class Pythia8::Particle &) --> double
#
#     phi(...) method of builtins.PyCapsule instance
#         phi(*args, **kwargs)
#         Overloaded function.
#
#         1. phi(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::phi(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#         2. phi(v1: pythia8.Vec4, v2: pythia8.Vec4, n: pythia8.Vec4) -> float
#
#         C++: Pythia8::phi(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
#     theta(...) method of builtins.PyCapsule instance
#         theta(v1: pythia8.Vec4, v2: pythia8.Vec4) -> float
#
#         C++: Pythia8::theta(const class Pythia8::Vec4 &, const class Pythia8::Vec4 &) --> double
#
# FILE
#     /opt/miniconda3/envs/hep-dl/lib/python3.9/site-packages/pythia8.so

# %% [markdown]
# ### 1. Charged-particle multiplicity at RHIC
#
# This setup initializes **proton-proton (pp) collisions at √s = 13 TeV** using **Pythia8** with **hard QCD processes** enabled. The key steps:
#
# - **Setting up beams & energy:** `Beams:idA = 2212`, `Beams:idB = 2212`, `Beams:eCM = 200`
# - **Physics processes:** `HardQCD:all = on` enables hard QCD interactions.
# - **Random seed:** `Random:setSeed = on`, `Random:seed = 42` ensures reproducibility.
# - Remember to change when simulating actual datasets! `Random:seed = 0` will use a unique seed based on the current time.
# - **Initialization:** `pythia.init()` estimates cross-sections and prepares the simulation.
#
# 🔗 Full list of configuration settings: [Online Pythia8 Manual](https://pythia.org//latest-manual/Welcome.html)
#
# - **Event generation:** `pythia.next()` produces the next event.
# - **Selecting final-state particles:**
#   - `particle.isFinal()`: Ensures only final state particles are counted.
#   - `particle.isCharged()`: Restricts to charged tracks.
#   - `|η| < 0.5`: Focuses on **mid-rapidity**, relevant for LHC central detectors.
# - **Final statistics:** `pythia.stat()` prints cross-sections and process details.
# - Properties of particles within events are documented at [Particle Class](https://pythia.org/latest-manual/ParticleProperties.html)
#
# This will produce **ROOT histograms** of:
# 1. **Charged particle multiplicity at mid-rapidity.**
# 2. **pThat (hard scattering scale) distribution.**

# %%
# Initialize Pythia
pythia = pythia8.Pythia()

# Set up LHC proton-proton collisions at 13 TeV
pythia.readString("Beams:idA = 2212")  # Proton
pythia.readString("Beams:idB = 2212")  # Proton
pythia.readString("Beams:eCM = 200.")  # Collision energy in GeV

# Enable QCD hard processes
pythia.readString("HardQCD:all = on")

# Limit the phase-space
# pythia.readString("PhaseSpace:pTHatMin = 10.")  # Minimum pT hard

# Enable parton showers and hadronization
pythia.readString("PartonLevel:MPI = on")   # Multiple Parton Interactions
pythia.readString("PartonLevel:ISR = on")   # Initial State Radiation
pythia.readString("PartonLevel:FSR = on")   # Final State Radiation

pythia.readString("HadronLevel:Decay = on")  # Enable hadron decays

# Initialize Pythia
pythia.init()

# ROOT histogram setup
canvas = ROOT.TCanvas("c1", "Multiplicity and pThat", 800, 600)

# Create histograms
h_multiplicity = ROOT.TH1F("h_multiplicity", "Charged Primary Multiplicity;N_{ch};Events", 50, 0, 50)
h_pThat = ROOT.TH1F("h_pThat", "p_{T}^{hat} Distribution;p_{T}^{hat} (GeV);Events", 50, 0, 50)

# Event loop
nEvents = 2000
for iEvent in range(nEvents):
    if not pythia.next():
        continue
    
    # Get pThat of the event (hard scale of the interaction)
    pThat = pythia.infoPython().pTHat()
    h_pThat.Fill(pThat)
    
    # Count charged primary final-state particles
    nCharged = 0
    for i in range(pythia.event.size()):

        # Get individual particle
        p = pythia.event[i]
        if p.isFinal() and p.isCharged() and abs(p.eta()) < 0.5:
            nCharged += 1
    
    h_multiplicity.Fill(nCharged)

# Draw histograms
canvas.Divide(1, 2)
canvas.cd(1)
h_multiplicity.Draw()
canvas.cd(2)
h_pThat.Draw()
canvas.Draw()

# Save histograms to ROOT file
output_file = ROOT.TFile("pp_multiplicity_pthat.root", "RECREATE")
h_multiplicity.Write()
h_pThat.Write()
output_file.Close()

# Print final statistics
pythia.stat()

print("\nSimulation complete. ROOT file 'pp_multiplicity_pthat.root' saved with histograms.")
# Out:
# Simulation complete. ROOT file 'pp_multiplicity_pthat.root' saved with histograms.
#
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.309      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 16 Feb 2023  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 13 Feb 2026 at 14:48:04    |  |
#  |  |                                                                              |  |
#  |  |   Program documentation and an archive of historic versions is found on:     |  |
#  |  |                                                                              |  |
#  |  |                               https://pythia.org/                            |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is authored by a collaboration consisting of:                       |  |
#  |  |                                                                              |  |
#  |  |   Christian Bierlich, Nishita Desai, Leif Gellersen, Ilkka Helenius, Philip  |  |
#  |  |   Ilten, Leif Lonnblad, Stephen Mrenna, Stefan Prestel, Christian Preuss,    |  |
#  |  |   Torbjorn Sjostrand, Peter Skands, Marius Utheim and Rob Verheyen.          |  |
#  |  |                                                                              |  |
#  |  |   The complete list of authors, including contact information and            |  |
#  |  |   affiliations, can be found on https://pythia.org/.                         |  |
#  |  |   Problems or bugs should be reported on email at authors@pythia.org.        |  |
#  |  |                                                                              |  |
#  |  |   The main program reference is C. Bierlich et al,                           |  |
#  |  |   'A comprehensive guide to the physics and usage of Pythia 8.3',            |  |
#  |  |   SciPost Phys. Codebases 8-r8.3 (2022) [arXiv:2203.11601 [hep-ph]]          |  |
#  |  |                                                                              |  |
#  |  |   PYTHIA is released under the GNU General Public Licence version 2 or later.|  |
#  |  |   Please respect the MCnet Guidelines for Event Generator Authors and Users. |  |
#  |  |                                                                              |  |
#  |  |   Disclaimer: this program comes without any guarantees.                     |  |
#  |  |   Beware of errors and use common sense when interpreting results.           |  |
#  |  |                                                                              |  |
#  |  |   Copyright (C) 2023 Torbjorn Sjostrand                                      |  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  *------------------------------------------------------------------------------*  |
#  |                                                                                    |
#  *------------------------------------------------------------------------------------*
#
#
#  *-------  PYTHIA Process Initialization  --------------------------*
#  |                                                                  |
#  | We collide p+ with p+ at a CM energy of 2.000e+02 GeV            |
#  |                                                                  |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | Subprocess                                    Code |   Estimated |
#  |                                                    |    max (mb) |
#  |                                                    |             |
#  |------------------------------------------------------------------|
#  |                                                    |             |
#  | g g -> g g                                     111 |   1.662e+02 |
#  | g g -> q qbar (uds)                            112 |   1.173e+00 |
#  | q g -> q g                                     113 |   1.492e+02 |
#  | q q(bar)' -> q q(bar)'                         114 |   3.401e+01 |
#  | q qbar -> g g                                  115 |   1.825e-01 |
#  | q qbar -> q' qbar' (uds)                       116 |   5.266e-02 |
#  | g g -> c cbar                                  121 |   4.941e-01 |
#  | q qbar -> c cbar                               122 |   2.186e-02 |
#  | g g -> b bbar                                  123 |   5.178e-03 |
#  | q qbar -> b bbar                               124 |   6.287e-04 |
#  |                                                                  |
#  *-------  End PYTHIA Process Initialization -----------------------*
#
#  *-------  PYTHIA Multiparton Interactions Initialization  ---------*
#  |                                                                  |
#  |                   sigmaNonDiffractive =    28.49 mb              |
#  |                                                                  |
#  |    pT0 =  1.06 gives sigmaInteraction =    85.02 mb: accepted    |
#  |                                                                  |
#  *-------  End PYTHIA Multiparton Interactions Initialization  -----*
#
#  *-------  PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings (changes only)  ------------------*
#  |                                                                                                                 |
#  | Name                                          |                      Now |      Default         Min         Max |
#  |                                               |                          |                                      |
#  | Beams:eCM                                     |                200.00000 |    14000.000         0.0             |
#  | HardQCD:all                                   |                       on |          off                         |
#  |                                                                                                                 |
#  *-------  End PYTHIA Flag + Mode + Parm + Word + FVec + MVec + PVec + WVec Settings  -----------------------------*
#
#  --------  PYTHIA Particle Data Table (changed only)  ------------------------------------------------------------------------------
#
#       id   name            antiName         spn chg col      m0        mWidth      mMin       mMax       tau0    res dec ext vis wid
#              no onMode   bRatio   meMode     products
#
#  no particle data has been changed from its default value
#
#  --------  End PYTHIA Particle Data Table  -----------------------------------------------------------------------------------------
#
#
#  --------  PYTHIA Info Listing  ----------------------------------------
#
#  Beam A: id =   2212, pz =  1.000e+02, e =  1.000e+02, m =  9.383e-01.
#  Beam B: id =   2212, pz = -1.000e+02, e =  1.000e+02, m =  9.383e-01.
#
#  In 1: id =    2, x =  2.247e-01, pdf =  6.487e-01 at Q2 =  3.365e+00.
#  In 2: id =   21, x =  9.879e-02, pdf =  1.197e+00 at same Q2.
#
#  Subprocess q g -> q g with code 113 is 2 -> 2.
#  It has sHat =  8.880e+02,    tHat = -3.378e+00,    uHat = -8.846e+02,
#        pTHat =  1.834e+00,   m3Hat =  3.300e-01,   m4Hat =  0.000e+00,
#     thetaHat =  1.234e-01,  phiHat =  6.442e-02.
#      alphaEM =  7.491e-03,  alphaS =  3.541e-01    at Q2 =  3.365e+00.
#
#  Impact parameter b =  1.848e-01 gives enhancement factor =  3.097e+00.
#  Max pT scale for MPI =  1.834e+00, ISR =  1.834e+00, FSR =  1.834e+00.
#  Number of MPI =     8, ISR =     3, FSRproc =     7, FSRreson =     0.
#
#  --------  End PYTHIA Info Listing  ------------------------------------
#
#  --------  PYTHIA Event Listing  (hard process)  -----------------------------------------------------------------------------------
#
#     no         id  name            status     mothers   daughters     colours      p_x        p_y        p_z         e          m
#    281         22  gamma               91   258     0     0     0     0     0      0.030     -0.100     -0.257      0.277      0.000
#    282         22  gamma               91   258     0     0     0     0     0      0.084      0.025     -0.233      0.248      0.000
#    283         22  gamma               91   263     0     0     0     0     0     -0.060     -0.030     -0.798      0.801      0.000
#    284         22  gamma               91   263     0     0     0     0     0     -0.075     -0.189     -0.991      1.011      0.000
#                                    Charge sum:  2.000           Momentum sum:      0.000      0.000      0.000    200.000    200.000
#
#  --------  End PYTHIA Event Listing  -----------------------------------------------------------------------------------------------
#  PYTHIA Warning in StringFragmentation::fragmentToJunction: bad convergence junction rest frame
#
#  Pythia::next(): 1000 events have been generated
#  PYTHIA Error in StringFragmentation::fragment: stuck in joining
#  PYTHIA Error in Pythia::next: hadronLevel failed; try again
#  PYTHIA Error in BeamRemnants::setKinematics: kinematics construction failed
#
#  *-------  PYTHIA Event and Cross Section Statistics  -------------------------------------------------------------*
#  |                                                                                                                 |
#  | Subprocess                                    Code |            Number of events       |      sigma +- delta    |
#  |                                                    |       Tried   Selected   Accepted |     (estimated) (mb)   |
#  |                                                    |                                   |                        |
#  |-----------------------------------------------------------------------------------------------------------------|
#  |                                                    |                                   |                        |
#  | g g -> g g                                     111 |        4989        984        984 |   3.296e+01  5.899e-01 |
#  | g g -> q qbar (uds)                            112 |          38         16         16 |   3.897e-01  5.020e-02 |
#  | q g -> q g                                     113 |        4570        848        848 |   2.827e+01  5.778e-01 |
#  | q q(bar)' -> q q(bar)'                         114 |        1033        147        147 |   5.320e+00  2.175e-01 |
#  | q qbar -> g g                                  115 |           5          1          1 |   4.223e-02  4.223e-02 |
#  | q qbar -> q' qbar' (uds)                       116 |           0          0          0 |   0.000e+00  0.000e+00 |
#  | g g -> c cbar                                  121 |          13          4          4 |   1.076e-01  4.045e-02 |
#  | q qbar -> c cbar                               122 |           1          0          0 |   0.000e+00  0.000e+00 |
#  | g g -> b bbar                                  123 |           0          0          0 |   0.000e+00  0.000e+00 |
#  | q qbar -> b bbar                               124 |           0          0          0 |   0.000e+00  0.000e+00 |
#  |                                                    |                                   |                        |
#  | sum                                                |       10649       2000       2000 |   6.709e+01  8.574e-01 |
#  |                                                                                                                 |
#  *-------  End PYTHIA Event and Cross Section Statistics ----------------------------------------------------------*
#
#  *-------  PYTHIA Error and Warning Messages Statistics  ----------------------------------------------------------*
#  |                                                                                                                 |
#  |  times   message                                                                                                |
#  |                                                                                                                 |
#  |      1   Error in BeamRemnants::setKinematics: kinematics construction failed                                   |
#  |      1   Error in Pythia::next: hadronLevel failed; try again                                                   |
#  |      1   Error in StringFragmentation::fragment: stuck in joining                                               |
#  |     13   Warning in StringFragmentation::fragmentToJunction: bad convergence junction rest frame                |
#  |                                                                                                                 |
#  *-------  End PYTHIA Error and Warning Messages Statistics  ------------------------------------------------------*

# %% [markdown]
# The simulation successfully generated **2000 pp collision events** at **200 GeV**. Key takeaways:
#
# #### **ROOT Histograms**
# 1. **Charged Particle Multiplicity (`|η| < 0.5`)**
#     - The most typical event activity observable.
#
# 2. **pThat Distribution (Hard Scattering Scale)**
#    - Represents the **transverse momentum of the hardest partonic interaction**.
#    - Higher pThat values correspond to **harder scatterings** (e.g., jet events).
#
# #### **Pythia Event Summary**
# - **Process contributions:** Lists subprocesses like **gg → gg, qq → qq’**, with their estimated cross-sections.
# - **Final statistics:** Confirms event generation success.
# - **Warnings/Errors:**
#   - Some fragmentation errors due to hadronization failures (doesn't affect the result).
#   - Momentum conservation warnings (minor numerical effects).
#
# #### **Play with it**
# - **Filter by transverse momentum** (`pT > 0.15 GeV`) to be more realistic.
# - What happens when we limit the phase space for pTHat?

# %% [markdown]
# ### 2. Studying Multiplicity and MPI in events at 7 TeV
#
# Now, we simulate **Non-Single Diffractive (NSD) events** at the **LHC energy of 7 TeV**.
# Key updates in this setup:
# - **SoftQCD:nonDiffractive = on** → Selects NSD events instead of hard QCD interactions.
# - **MultipartonInteractions:pT0Ref = 3.0** → Controls the minimum **pT scale** for MPI.
#
# We will look at:
# 2. **Number of Multiple Parton Interactions (MPI)** per event.
# 3. **Correlation between multiplicity and MPI** (2D histogram).
# 4. **Comparison with experimental data** from **CMS** (https://www.hepdata.net/record/57914)
#
# The multiplicity histogram is **normalized** for direct data comparison.
# A **log-scale y-axis** is applied to better visualize distribution tails.

# %%
# Initialize Pythia
pythia = pythia8.Pythia()

# Set up LHC proton-proton collisions at 7 TeV
pythia.readString("Beams:idA = 2212")  # Proton
pythia.readString("Beams:idB = 2212")  # Proton
pythia.readString("Beams:eCM = 7000.")  # Collision energy in GeV

# Enable SoftQCD Non-Single Diffractive (NSD) events
pythia.readString("SoftQCD:nonDiffractive = on")

# Minimum pT for multiple parton interactions (user can modify)
pythia.readString("MultipartonInteractions:pT0Ref = 3.0")

# Enable MPI, ISR, FSR
pythia.readString("PartonLevel:MPI = on")
pythia.readString("PartonLevel:ISR = on")
pythia.readString("PartonLevel:FSR = on")

# Enable hadron decays
pythia.readString("HadronLevel:Decay = on")

# Initialize Pythia
pythia.init()

# ROOT histogram setup
canvas = ROOT.TCanvas("c2", "Multiplicity, n_MPI, and 2D Histogram", 900, 600)

# Create histograms
h_multiplicity = ROOT.TH1F("h_multiplicity", "Charged Primary Multiplicity;N_{ch};Normalized Events", 50, 0, 50)
h_nMPI = ROOT.TH1F("h_nMPI", "Number of MPI;N_{MPI};Events", 25, 0, 25)
h_2D = ROOT.TH2F("h_2D", "Multiplicity vs. Number of MPI;N_{MPI};N_{ch}", 25, 0, 25, 50, 0, 50)

# Event loop
nEvents = 2000
for iEvent in range(nEvents):
    if not pythia.next():
        continue
    
    # Get number of multiple parton interactions (MPI)
    nMPI = pythia.infoPython().nMPI()
    h_nMPI.Fill(nMPI)
    
    # Count charged primary final-state particles
    nCharged = 0
    for i in range(pythia.event.size()):
        p = pythia.event[i]
        if p.isFinal() and p.isCharged() and abs(p.eta()) < 0.5 and p.pT() > 0.15:
            nCharged += 1
    
    h_multiplicity.Fill(nCharged)
    h_2D.Fill(nMPI, nCharged)

# Normalize multiplicity histogram
h_multiplicity.Scale(1.0 / nEvents)

# Load experimental data from ROOT file
exp_file = ROOT.TFile("HEPData-ins879315-v1-Table_12.root")
data_dir = exp_file.Get("Table 12")
graph_exp = data_dir.Get("Graph1D_y1")

# Draw histograms
canvas.Divide(2, 2)
canvas.cd(1)
canvas.GetPad(1).SetLogy()  # Set log scale for y-axis
h_multiplicity.Draw("HIST")
graph_exp.SetMarkerStyle(20)
graph_exp.SetMarkerColor(ROOT.kRed)
graph_exp.Draw("P SAME")

canvas.cd(2)
h_nMPI.Draw()
canvas.cd(3)
h_2D.Draw("COLZ")
canvas.Draw()

# Save histograms to ROOT file
output_file = ROOT.TFile("lhc_mpi_analysis.root", "RECREATE")
h_multiplicity.Write()
h_nMPI.Write()
h_2D.Write()
output_file.Close()

# Print final statistics
pythia.stat()

print("\nSimulation complete. ROOT file 'lhc_mpi_analysis.root' saved with histograms.")
# Out:
# Simulation complete. ROOT file 'lhc_mpi_analysis.root' saved with histograms.
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c2
# Warning in <TROOT::Append>: Replacing existing TH1: h_multiplicity (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_nMPI (Potential memory leak).
# Warning in <TROOT::Append>: Replacing existing TH1: h_2D (Potential memory leak).

# %% [markdown]
# Now we simulated **2000 pp collision events** at **7 TeV**. Key takeaways:
#
# 1. **Comparison of `N_ch` and data**
#    - Shows that something needs to be tuned!
#
# 2. **Number of MPI (`N_MPI`)**
#    - Number of **multiple parton interactions** per event.
#
# 3. **Multiplicity vs. MPI (2D Histogram)**
#    - Shows **correlation between `N_ch` and `N_MPI`**.
#    - Higher MPI is the dominant source of higher multiplicity
#
# #### **Play with it**
# - What happens to `N_ch` and `N_MPI` as we change the MPI minimum pT parameter pT0Ref?
# - What value of pT0Ref is optimal to reproduce the CMS data?

# %% [markdown]
# ### 3. J/ψ Production and Decay in pp Collisions
#
# In this exercise, we simulate **J/ψ production** in **proton-proton collisions at 7 TeV** and store key event and particle information in a structured **ROOT tree**.
#
# #### **What we do**
# - **Accessing PDG IDs**:
#   - We identify the **J/ψ** using its **PDG ID = 443**.
#   - Muons are selected by comparing their **PDG ID = 13**.
#   - Decay modes of the particles can be turned on/off. We select only the di-muon channel `443:onIfMatch = 13 -13`
#
# - **Tracking Parent-Daughter Relationships**:
#   - Each **muon’s mother index** is stored (`mu_motherID`).
#   - The **PDG ID of the mother** is also store (`mu_motherPDG`).
#
# - **Tree Structure**:
#   - **Global Event information**: `nMPI` and `nCh`
#   - **J/ψ Information**: `pT`, `y`, `φ`, and **its index in the event** (`jpsi_id`).
#   - **Muon Information**: `pT`, `η`, `φ`, **charge**, **mother index**, and **mother PDG ID**.

# %%
# Initialize Pythia
pythia = pythia8.Pythia()

# Set up LHC proton-proton collisions at 7 TeV
pythia.readString("Beams:idA = 2212")  # Proton
pythia.readString("Beams:idB = 2212")  # Proton
pythia.readString("Beams:eCM = 7000.")  # Collision energy in GeV

# Enable J/psi production
pythia.readString("Charmonium:all = on")

# Ensure J/Psi is decaying only into dimuons
pythia.readString("443:onMode = off")       # Turn off all J/Psi decays
pythia.readString("443:onIfMatch = 13 -13") # Enable only J/Psi -> mu+ mu-


# Enable MPI, ISR, FSR
pythia.readString("PartonLevel:MPI = on")
pythia.readString("PartonLevel:ISR = on")
pythia.readString("PartonLevel:FSR = on")

# Enable hadron decays
pythia.readString("HadronLevel:Decay = on")

# Initialize Pythia
pythia.init()

# Create a ROOT file and tree
output_file = ROOT.TFile("jpsi_production.root", "RECREATE")
tree = ROOT.TTree("T", "J/psi Production Data")

# Define event-level variables
nMPI = ROOT.std.vector('int')(1)
nCh = ROOT.std.vector('int')(1)

# Define J/psi mother variables
jpsi_pT = ROOT.std.vector('float')()
jpsi_y = ROOT.std.vector('float')()
jpsi_phi = ROOT.std.vector('float')()
jpsi_id = ROOT.std.vector('int')()

# Define muon daughter variables
mu_pT = ROOT.std.vector('float')()
mu_eta = ROOT.std.vector('float')()
mu_phi = ROOT.std.vector('float')()
mu_charge = ROOT.std.vector('int')()
mu_motherID = ROOT.std.vector('int')()
mu_motherPDG = ROOT.std.vector('int')()

# Attach branches to the tree
tree.Branch("nMPI", nMPI)
tree.Branch("nCh", nCh)
tree.Branch("jpsi_pT", jpsi_pT)
tree.Branch("jpsi_y", jpsi_y)
tree.Branch("jpsi_phi", jpsi_phi)
tree.Branch("jpsi_id", jpsi_id)
tree.Branch("mu_pT", mu_pT)
tree.Branch("mu_eta", mu_eta)
tree.Branch("mu_phi", mu_phi)
tree.Branch("mu_charge", mu_charge)
tree.Branch("mu_motherID", mu_motherID)
tree.Branch("mu_motherPDG", mu_motherPDG)

# Event loop
nEvents = 5000
for iEvent in range(nEvents):
    if not pythia.next():
        continue
    
    # Clear vectors for new event
    nMPI[0] = pythia.infoPython().nMPI()
    
    nCharged = 0
    for i in range(pythia.event.size()):
        p = pythia.event[i]
        if p.isFinal() and p.isCharged() and abs(p.eta()) < 2.5 and p.pT() > 0.15:
            nCharged += 1
    nCh[0] = nCharged
    
    jpsi_pT.clear()
    jpsi_y.clear()
    jpsi_phi.clear()
    jpsi_id.clear()
    mu_pT.clear()
    mu_eta.clear()
    mu_phi.clear()
    mu_charge.clear()
    mu_motherID.clear()
    mu_motherPDG.clear()
    
    # Loop over particles to find J/psi and its decay products
    for i in range(pythia.event.size()):
        p = pythia.event[i]
        
        if abs(p.id()) == 443:  # J/psi identification
            jpsi_pT.push_back(p.pT())
            jpsi_y.push_back(p.y())
            jpsi_phi.push_back(p.phi())
            jpsi_id.push_back(i)
        
        # Find muon daughters of J/psi
        if abs(p.id()) == 13 and p.isFinal():  # Muon or anti-muon
            mu_pT.push_back(p.pT())
            mu_eta.push_back(p.eta())
            mu_phi.push_back(p.phi())
            mu_charge.push_back(int(p.id() / abs(p.id())))  # +1 for mu+, -1 for mu-
            mu_motherID.push_back(p.mother1())
            mu_motherPDG.push_back(pythia.event[p.mother1()].id())
    
    tree.Fill()

# Save tree and close file
output_file.Write()
output_file.Close()

# Print final statistics
pythia.stat()

print("\nSimulation complete. ROOT file 'jpsi_production.root' saved with J/psi data.")
